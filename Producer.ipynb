# %%
# Define Azure credentials
# !pip install python-dotenv
import os
from dotenv import load_dotenv

event_hub_namespace = os.environ.get("event_hub_namespace")

passengers_eventhub_name=os.environ.get("passengers_eventhub_name")
passengers_conn_str_prod=os.environ.get("passengers_conn_str_prod")

drivers_eventhub_name=os.environ.get("drivers_eventhub_name")
drivers_conn_str_prod=os.environ.get("drivers_conn_str_prod")

# %%
# !pip install confluent_kafka fastavro
# Out:
# Collecting confluent_kafka
#   Downloading confluent_kafka-2.10.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (22 kB)
# Collecting fastavro
#   Downloading fastavro-1.10.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.5 kB)
# Downloading confluent_kafka-2.10.0-cp311-cp311-manylinux_2_28_x86_64.whl (3.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 34.7 MB/s eta 0:00:00
# Downloading fastavro-1.10.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 72.3 MB/s eta 0:00:00
# Installing collected packages: fastavro, confluent_kafka
# Successfully installed confluent_kafka-2.10.0 fastavro-1.10.0

# %%
#!/usr/bin/env python3
import json, time, random, uuid, io
import threading
import math
import numpy as np
from datetime import datetime
from confluent_kafka import Producer
import fastavro
from fastavro import parse_schema

# Kafka configurations
conf_passengers = {
    'bootstrap.servers': f"{event_hub_namespace}.servicebus.windows.net:9093",
    'security.protocol': 'SASL_SSL',
    'sasl.mechanisms': 'PLAIN',
    'sasl.username': '$ConnectionString',
    'sasl.password': passengers_conn_str_prod,
    'client.id': 'producer-passenger'
}
conf_drivers = {
    'bootstrap.servers': f"{event_hub_namespace}.servicebus.windows.net:9093",
    'security.protocol': 'SASL_SSL',
    'sasl.mechanisms': 'PLAIN',
    'sasl.username': '$ConnectionString',
    'sasl.password': drivers_conn_str_prod,
    'client.id': 'producer-driver'
}

# Load schemas
with open("/content/passengerschemav2.json") as f:
    passenger_schema = parse_schema(json.load(f))
with open("driver_schema.json") as f:
    driver_schema = parse_schema(json.load(f))

# Initialize Kafka producers
producer_pass = Producer(**conf_passengers)
producer_drv = Producer(**conf_drivers)

def delivery_report(err, msg):
    if err is not None:
        print(f"Delivery failed: {err}")
    else:
        print(f"Delivered to {msg.topic()} [{msg.partition()}] offset {msg.offset()}")

def avro_serialize(record, schema):
    with io.BytesIO() as buf:
        fastavro.schemaless_writer(buf, schema, record)
        return buf.getvalue()

def store_passenger_request(record):
    try:
        # Serialize to AVRO
        avro_data = avro_serialize(record, passenger_schema)

        # Send to EventHub using Confluent Kafka
        producer_pass.produce(
            topic=passengers_eventhub_name,
            value=avro_data,
            callback=delivery_report
        )
        producer_pass.poll(0)
        print(f"[EventHub] Sent passenger request {record['request_id']}")
    except Exception as e:
        print(f"[EventHub] Error: {e}")

def store_driver_update(record):
    try:
        avro_data = avro_serialize(record, driver_schema)

        producer_drv.produce(
            topic=drivers_eventhub_name,
            value=avro_data,
            callback=delivery_report
        )
        producer_drv.poll(0)
        print(f"[EventHub] Sent driver update for {record['driver_id']}")
    except Exception as e:
        print(f"[EventHub] Error: {e}")

# Creating system message without OpenAI keys
def generate_system_message(passenger_id):
    messages = [
        "I'll be there in 5 minutes, please wait outside.",
        "Just looking for parking, be right there.",
        "Traffic is bad, running a bit late.",
        "I'm at the pickup spot, where are you?",
        "Changed my mind, can we go to a different place?",
        "Do you have room for my luggage?",
        "Can we make a quick stop on the way?",
        "I'm wearing a red jacket, look for me.",
        "Could you turn the AC up please?",
        "Is it ok if I bring my pet?"
    ]
    return random.choice(messages)

class City:
    def __init__(self, city_center, city_radius, drivers, passengers, base_speed=30):
        city_center = (float(city_center[0]), float(city_center[1]))
        self.city_center = city_center
        self.city_radius = city_radius
        self.drivers = drivers
        self.passengers = passengers
        self.base_speed = base_speed
        self.simulation_time = 0  # minutes
        self.demand_multiplier = 1.0
        self.pricing_multiplier = 1.0
        self.speed_factor = 1.0
        self.base_lambda = 3
        self.lock = threading.Lock()

    def update_demand_and_pricing(self):
        minutes_in_day = self.simulation_time % (24 * 60)
        hour = minutes_in_day // 60
        if 7 <= hour < 9 or 17 <= hour < 19:
            base_lambda = 10
            base_speed_factor = 0.7
        else:
            base_lambda = 3
            base_speed_factor = 1.0
        poisson_demand = np.random.poisson(base_lambda)
        self.demand_multiplier = max(1.0, 1.0 + (poisson_demand - base_lambda) / base_lambda)
        self.pricing_multiplier = self.demand_multiplier
        self.speed_factor = base_speed_factor
        self.base_lambda = base_lambda
        print(f"[Demand Update] Time: {hour:02d}:00, Poisson Demand: {poisson_demand}, "
              f"Demand Multiplier: {self.demand_multiplier:.2f}, "
              f"Pricing Multiplier: {self.pricing_multiplier:.2f}, "
              f"Speed Factor: {self.speed_factor:.2f}, Base Lambda: {self.base_lambda}")

    def update_driver_workforce(self):
        minutes_in_day = self.simulation_time % (24 * 60)
        hour = minutes_in_day // 60
        if hour < 6 or hour >= 22:
            offline_prob = 0.03
            online_prob = 0.005
        elif 6 <= hour < 10:
            offline_prob = 0.01
            online_prob = 0.02
        else:
            offline_prob = 0.015
            online_prob = 0.01
        with self.lock:
            for driver in self.drivers:
                if driver.status in ("AVAILABLE", "ON_RIDE"):
                    if random.random() < offline_prob:
                        driver.status = "OFFLINE"
                        print(f"[Driver Workforce] {driver.driver_id} went OFFLINE.")
                elif driver.status == "OFFLINE":
                    if random.random() < online_prob:
                        driver.status = "AVAILABLE"
                        print(f"[Driver Workforce] {driver.driver_id} came ONLINE.")

    def calculate_distance(self, loc1, loc2):
        lat1, lon1 = loc1
        lat2, lon2 = loc2
        lat_diff = (lat2 - lat1) * 111
        lon_diff = (lon2 - lon1) * 111 * math.cos(math.radians((lat1 + lat2) / 2))
        return math.sqrt(lat_diff ** 2 + lon_diff ** 2)

    def select_closest_driver(self, pickup_location, request_start_time, desired_vehicle_type, max_wait_time=None):
        if max_wait_time is None:
            max_wait_time = random.randint(5, 10)
        while True:
            with self.lock:
                closest_driver = None
                min_distance = float('inf')
                for driver in self.drivers:
                    if driver.status == "AVAILABLE" and driver.vehicle_type == desired_vehicle_type:
                        driver_loc = (driver.current_lat, driver.current_lon)
                        dist = self.calculate_distance(pickup_location, driver_loc)
                        if dist < min_distance:
                            min_distance = dist
                            closest_driver = driver
                if closest_driver:
                    closest_driver.status = "ON_RIDE"
                    print(f"[Driver Assigned] {closest_driver.driver_id} with {desired_vehicle_type} assigned for pickup at {pickup_location}.")
                    return closest_driver
            if time.time() - request_start_time > max_wait_time:
                print(f"[Queue] Passenger left the queue due to excessive wait time (no matching {desired_vehicle_type} driver available).")
                return None
            print(f"[Driver Queue] No available driver with type {desired_vehicle_type}. Waiting...")
            time.sleep(1)

    def calculate_trip_details(self, pickup_location, dropoff_location):
        distance = self.calculate_distance(pickup_location, dropoff_location)
        trip_duration_sec = (distance / (self.base_speed * self.speed_factor)) * 3600
        base_fare = 2.5
        per_km_rate = 1.5
        fare = (base_fare + per_km_rate * distance) * self.pricing_multiplier * self.demand_multiplier
        return distance, trip_duration_sec, fare

    def simulate_ride(self, request, driver):
        pickup_dict = request['pickup_location']
        dropoff_dict = request['dropoff_location']
        pickup_loc = (pickup_dict['latitude'], pickup_dict['longitude'])
        dropoff_loc = (dropoff_dict['latitude'], dropoff_dict['longitude'])
        driver_loc = (driver.current_lat, driver.current_lon)
        print(f"[Ride Start] {driver.driver_id} is heading to pickup location {pickup_dict} for passenger {request['passenger_id']}.")
        distance_to_pickup = self.calculate_distance(pickup_loc, driver_loc)
        travel_time_to_pickup = (distance_to_pickup / (self.base_speed * self.speed_factor)) * 3600
        print(f"[Pickup] {driver.driver_id} is {distance_to_pickup:.2f} km away; estimated time: {travel_time_to_pickup:.2f} sec.")
        time.sleep(travel_time_to_pickup * 0.01)
        with self.lock:
            driver.current_lat = pickup_dict['latitude']
            driver.current_lon = pickup_dict['longitude']
        print(f"[Pickup Complete] {driver.driver_id} has reached the pickup location.")
        distance, trip_duration_sec, fare = self.calculate_trip_details(pickup_loc, dropoff_loc)
        print(f"[Trip Details] Distance: {distance:.2f} km, Trip Time: {trip_duration_sec:.2f} sec, Estimated Fare: {fare:.2f}.")
        time.sleep(trip_duration_sec * 0.01)
        with self.lock:
            driver.current_lat = dropoff_dict['latitude']
            driver.current_lon = dropoff_dict['longitude']
            driver.status = "AVAILABLE"
        print(f"[Trip Complete] {driver.driver_id} has dropped off passenger {request['passenger_id']} at {dropoff_dict}.")
        ride_status = "COMPLETED"
        if random.random() < 0.05:
            ride_status = "CANCELLED"
            trip_duration_sec = trip_duration_sec * random.uniform(0.1, 0.5)
        elif random.random() < 0.02:
            ride_status = "IN_PROGRESS"
            trip_duration_sec = trip_duration_sec * random.uniform(0.3, 0.8)
        request_time = request["timestamp"]
        acceptance_delay = random.randint(30000, 180000)
        accepted_time = request_time + acceptance_delay
        is_anomaly = random.random() < 0.03
        if is_anomaly:
            if random.random() < 0.5:
                trip_duration_sec = trip_duration_sec * random.uniform(0.2, 0.4)
            else:
                trip_duration_sec = trip_duration_sec * random.uniform(1.5, 2.5)
                fare = fare * random.uniform(1.5, 2.0)
        if is_anomaly:
            print(f"[ANOMALY] Detected anomalous ride data: {request['request_id']} - Duration: {trip_duration_sec:.2f}s, Fare: {fare:.2f}")
        passenger_request_record = {
            "request_id": request["request_id"],
            "passenger_id": request["passenger_id"],
            "timestamp": request["timestamp"],
            "pickup_location": request["pickup_location"],
            "dropoff_location": request["dropoff_location"],
            "vehicle_type": request["vehicle_type"],
            "passenger_preferences": request["passenger_preferences"],
            "payment_info": request["payment_info"],
            "estimated_fare": float(fare),
            "text_messages": request["text_messages"],
            "driver_rating": request["driver_rating"],
            "status": ride_status,
            "driver_id": driver.driver_id,
            "request_timestamp": request["timestamp"],
            "accepted_timestamp": request["timestamp"] + int(travel_time_to_pickup * 1000),
            "ride_duration": float(trip_duration_sec)
        }
        driver_update_record = {
            "driver_id": driver.driver_id,
            "timestamp": int(time.time() * 1000),
            "latitude": driver.current_lat,
            "longitude": driver.current_lon,
            "status": driver.status
        }
        print(f"[Records] Passenger Request: {passenger_request_record}")
        print(f"[Records] Driver Update: {driver_update_record}")
        store_passenger_request(passenger_request_record)
        store_driver_update(driver_update_record)
        return passenger_request_record, driver_update_record

    def process_request(self, request):
        pickup_dict = request['pickup_location']
        pickup_tuple = (pickup_dict['latitude'], pickup_dict['longitude'])
        print(f"[Process Request] Received ride request {request['request_id']} from passenger {request['passenger_id']}.")
        self.update_demand_and_pricing()
        request_start_time = time.time()
        desired_vehicle_type = request["vehicle_type"]
        driver = self.select_closest_driver(pickup_tuple, request_start_time, desired_vehicle_type)
        if driver:
            ride_thread = threading.Thread(target=self.simulate_ride, args=(request, driver))
            ride_thread.start()
        else:
            print(f"[Process Request] Passenger {request['passenger_id']} canceled request {request['request_id']} due to wait timeout.")

    def run_simulation(self, duration_seconds=60, request_interval=2):
        print("[Simulation Start] Running simulation for", duration_seconds, "seconds.")
        start_time = time.time()
        while time.time() - start_time < duration_seconds:
            self.simulation_time += 1
            print(f"\n[Simulation Time] Minute {self.simulation_time}")
            self.update_demand_and_pricing()
            self.update_driver_workforce()

            with self.lock:
                working_count = sum(1 for d in self.drivers if d.status != "OFFLINE")
                total_drivers = len(self.drivers)
                print(f"[Snapshot] {working_count}/{total_drivers} drivers working.")
                for driver in self.drivers:
                    driver_update = driver.generate_driver_update()
                    store_driver_update(driver_update)

            num_requests = np.random.poisson(self.base_lambda * 0.5)
            print(f"[New Requests] Generating {num_requests} ride request(s) this cycle.")
            for _ in range(num_requests):
                if self.passengers:
                    passenger = random.choice(self.passengers)
                    request = passenger.make_request()
                    print(f"[New Request] {request['request_id']} generated by passenger {request['passenger_id']}.")
                    self.process_request(request)
                else:
                    print("[New Request] No passengers available.")
            time.sleep(request_interval)
        print("[Simulation End] Simulation complete.")
        # Flush the producers
        producer_pass.flush()
        producer_drv.flush()

class Passenger:
    def __init__(self, passenger_id, city_center, city_radius):
        city_center = (float(city_center[0]), float(city_center[1]))
        self.passenger_id = passenger_id
        self.city_center = city_center
        self.city_radius = city_radius
        self.name = f"Passenger {passenger_id}"
        self.home = {"latitude": city_center[0] + random.uniform(-city_radius / 100, city_radius / 100),
                     "longitude": city_center[1] + random.uniform(-city_radius / 100, city_radius / 100)}
        self.work = {"latitude": city_center[0] + random.uniform(-city_radius / 100, city_radius / 100),
                     "longitude": city_center[1] + random.uniform(-city_radius / 100, city_radius / 100)}

    def make_request(self):
        if random.random() > 0.5:
            pickup = self.home
            dropoff = self.work
        else:
            pickup = self.work
            dropoff = self.home

        vehicle_types = ["ECONOMY", "LUXURY", "POOL", "SUV"]
        weights = [0.75, 0.1, 0.05, 0.1]
        vehicle_type = random.choices(vehicle_types, weights=weights, k=1)[0]

        music_choices = ["NO_PREFERENCE", "POP", "ROCK", "CLASSICAL", "JAZZ", "HIP_HOP"]
        passenger_preferences = {
            "music": random.choice(music_choices),
            "temperature": random.randint(18, 26),
            "quiet_ride": random.choice([True, False])
        }
        payment_methods = ["CASH", "CREDIT_CARD", "DEBIT_CARD", "PAYPAL", "APPLE_PAY", "GOOGLE_PAY"]
        payment_info = {
            "payment_method": random.choice(payment_methods),
            "coupon_codes": [] if random.random() >= 0.15 else [f"SAVE{random.randint(10,50)}"],
            "loyalty_points_used": random.randint(0, 100) if random.random() < 0.1 else None
        }
        request = {
            "request_id": f"REQ-{int(time.time())}-{random.randint(1000,9999)}",
            "passenger_id": self.passenger_id,
            "timestamp": int(time.time() * 1000),
            "pickup_location": pickup,
            "dropoff_location": dropoff,
            "vehicle_type": vehicle_type,
            "passenger_preferences": passenger_preferences,
            "payment_info": payment_info,
            "estimated_fare": 0.0,
            "text_messages": [],
            "driver_rating": round(random.uniform(1.0, 5.0), 1) if random.random() < 0.4 else None
        }
        if random.random() < 0.15:
            ai_content = generate_system_message(self.passenger_id)
            new_message = {
                "message_id": f"SYS-{int(time.time())}-{random.randint(1000,9999)}",
                "sender": "PASSENGER",
                "content": ai_content,
                "sent_at": int(time.time() * 1000)
            }
            request["text_messages"].append(new_message)

        print(f"[Make Request] Passenger {self.passenger_id} created request {request['request_id']}.")
        return request

class Driver:
    def __init__(self, driver_id, city_center, city_radius, vehicle_type=None):
        city_center = (float(city_center[0]), float(city_center[1]))
        self.driver_id = driver_id
        self.name = f"Driver {driver_id}"
        self.city_center = city_center
        self.city_radius = city_radius

        self.vehicle_types = ["ECONOMY", "LUXURY", "POOL", "SUV"]
        weights = [0.8, 0.08, 0.02, 0.1]
        self.vehicle_type = random.choices(self.vehicle_types, weights=weights, k=1)[0] if vehicle_type is None else vehicle_type

        self.current_lat = city_center[0] + random.uniform(-city_radius / 100, city_radius / 100)
        self.current_lon = city_center[1] + random.uniform(-city_radius / 100, city_radius / 100)

        self.status = "AVAILABLE" if random.random() < 0.7 else "OFFLINE"

        print(f"[Driver Init] {self.driver_id} initialized at ({self.current_lat:.4f}, {self.current_lon:.4f}) with status {self.status} and vehicle type {self.vehicle_type}.")

    def update_location(self, new_lat, new_lon):
        self.current_lat = new_lat
        self.current_lon = new_lon

    def update_status(self, new_status):
        self.status = new_status

    def simulate_movement(self, target_location, base_speed=30, speed_factor=1.0):
        lat_diff = (target_location["latitude"] - self.current_lat) * 111
        lon_diff = (target_location["longitude"] - self.current_lon) * 111 * math.cos(math.radians((self.current_lat + target_location["latitude"]) / 2))
        distance = math.sqrt(lat_diff ** 2 + lon_diff ** 2)
        travel_time_sec = (distance / (base_speed * speed_factor)) * 3600
        time.sleep(travel_time_sec * 0.01)
        self.update_location(target_location["latitude"], target_location["longitude"])

    def generate_driver_update(self):
        driver_update_record = {
            "driver_id": self.driver_id,
            "timestamp": int(time.time() * 1000),
            "latitude": self.current_lat,
            "longitude": self.current_lon,
            "status": self.status
        }
        return driver_update_record

# Initialize and run the simulation
city_center = (40.75, -73.99)
city_radius = 15  # km

drivers = [Driver(f"driver_{i:03d}", city_center, city_radius) for i in range(300)]
passengers = [Passenger(f"P{i:05d}", city_center, city_radius) for i in range(600)]
city = City(city_center, city_radius, drivers, passengers)

city.run_simulation(duration_seconds=480, request_interval=1)
# Out:
# Streaming output truncated to the last 5000 lines.
# Delivered to group3-driver-updates [1] offset 669252
# [EventHub] Sent driver update for driver_298
# [Pickup Complete] driver_241 has reached the pickup location.
# [Trip Details] Distance: 12.76 km, Trip Time: 1530.96 sec, Estimated Fare: 21.64.
# [Trip Complete] driver_179 has dropped off passenger P00067 at {'latitude': 40.79251988447475, 'longitude': -74.13498218122068}.
# [Records] Passenger Request: {'request_id': 'REQ-1745433066-7269', 'passenger_id': 'P00067', 'timestamp': 1745433066956, 'pickup_location': {'latitude': 40.66569055263897, 'longitude': -73.8995277646427}, 'dropoff_location': {'latitude': 40.79251988447475, 'longitude': -74.13498218122068}, 'vehicle_type': 'LUXURY', 'passenger_preferences': {'music': 'HIP_HOP', 'temperature': 25, 'quiet_ride': True}, 'payment_info': {'payment_method': 'CREDIT_CARD', 'coupon_codes': [], 'loyalty_points_used': None}, 'estimated_fare': 108.19102059844661, 'text_messages': [], 'driver_rating': 3.4, 'status': 'COMPLETED', 'driver_id': 'driver_179', 'request_timestamp': 1745433066956, 'accepted_timestamp': 1745434180524, 'ride_duration': 2915.9013932352627}
# [Records] Driver Update: {'driver_id': 'driver_179', 'timestamp': 1745433107251, 'latitude': 40.79251988447475, 'longitude': -74.13498218122068, 'status': 'AVAILABLE'}
# Delivered to group3-passenger_requests [0] offset 241353
# [EventHub] Sent passenger request REQ-1745433066-7269
# Delivered to group3-driver-updates [1] offset 669253
# [EventHub] Sent driver update for driver_179
# [Trip Complete] driver_146 has dropped off passenger P00212 at {'latitude': 40.78712234632978, 'longitude': -74.09261235211903}.
# [Records] Passenger Request: {'request_id': 'REQ-1745433085-2762', 'passenger_id': 'P00212', 'timestamp': 1745433085030, 'pickup_location': {'latitude': 40.82363217129955, 'longitude': -73.89801356721907}, 'dropoff_location': {'latitude': 40.78712234632978, 'longitude': -74.09261235211903}, 'vehicle_type': 'ECONOMY', 'passenger_preferences': {'music': 'HIP_HOP', 'temperature': 21, 'quiet_ride': False}, 'payment_info': {'payment_method': 'CASH', 'coupon_codes': [], 'loyalty_points_used': None}, 'estimated_fare': 27.76731784878247, 'text_messages': [], 'driver_rating': 2.6, 'status': 'COMPLETED', 'driver_id': 'driver_146', 'request_timestamp': 1745433085030, 'accepted_timestamp': 1745433305314, 'ride_duration': 2021.3854279025977}
# [Records] Driver Update: {'driver_id': 'driver_146', 'timestamp': 1745433107448, 'latitude': 40.78712234632978, 'longitude': -74.09261235211903, 'status': 'AVAILABLE'}
# Delivered to group3-passenger_requests [0] offset 241354
# [EventHub] Sent passenger request REQ-1745433085-2762
# Delivered to group3-driver-updates [1] offset 669254
# [EventHub] Sent driver update for driver_146
# [Pickup Complete] driver_082 has reached the pickup location.
# [Trip Details] Distance: 5.51 km, Trip Time: 661.08 sec, Estimated Fare: 10.76.
# [Driver Assigned] driver_179 with LUXURY assigned for pickup at (40.77694916035576, -73.99327125348172).
# [Ride Start] driver_179 is heading to pickup location {'latitude': 40.77694916035576, 'longitude': -73.99327125348172} for passenger P00008.
# [Pickup] driver_179 is 12.03 km away; estimated time: 1444.19 sec.
#
# [Simulation Time] Minute 271
# [Demand Update] Time: 04:00, Poisson Demand: 6, Demand Multiplier: 2.00, Pricing Multiplier: 2.00, Speed Factor: 1.00, Base Lambda: 3
# [Driver Workforce] driver_006 went OFFLINE.
# [Driver Workforce] driver_262 came ONLINE.
# [Driver Workforce] driver_279 came ONLINE.
# [Snapshot] 46/300 drivers working.
# Delivered to group3-driver-updates [0] offset 670760
# [EventHub] Sent driver update for driver_000
# [EventHub] Sent driver update for driver_001
# [EventHub] Sent driver update for driver_002
# [EventHub] Sent driver update for driver_003
# [EventHub] Sent driver update for driver_004
# [EventHub] Sent driver update for driver_005
# [EventHub] Sent driver update for driver_006
# [EventHub] Sent driver update for driver_007
# [EventHub] Sent driver update for driver_008
# [EventHub] Sent driver update for driver_009
# [EventHub] Sent driver update for driver_010
# [EventHub] Sent driver update for driver_011
# [EventHub] Sent driver update for driver_012
# [EventHub] Sent driver update for driver_013
# [EventHub] Sent driver update for driver_014
# [EventHub] Sent driver update for driver_015
# [EventHub] Sent driver update for driver_016
# [EventHub] Sent driver update for driver_017
# [EventHub] Sent driver update for driver_018
# [EventHub] Sent driver update for driver_019
# [EventHub] Sent driver update for driver_020
# [EventHub] Sent driver update for driver_021
# [EventHub] Sent driver update for driver_022
# [EventHub] Sent driver update for driver_023
# [EventHub] Sent driver update for driver_024
# [EventHub] Sent driver update for driver_025
# [EventHub] Sent driver update for driver_026
# [EventHub] Sent driver update for driver_027
# [EventHub] Sent driver update for driver_028
# [EventHub] Sent driver update for driver_029
# [EventHub] Sent driver update for driver_030
# [EventHub] Sent driver update for driver_031
# [EventHub] Sent driver update for driver_032
# [EventHub] Sent driver update for driver_033
# [EventHub] Sent driver update for driver_034
# [EventHub] Sent driver update for driver_035
# [EventHub] Sent driver update for driver_036
# [EventHub] Sent driver update for driver_037
# [EventHub] Sent driver update for driver_038
# [EventHub] Sent driver update for driver_039
# [EventHub] Sent driver update for driver_040
# [EventHub] Sent driver update for driver_041
# [EventHub] Sent driver update for driver_042
# [EventHub] Sent driver update for driver_043
# [EventHub] Sent driver update for driver_044
# [EventHub] Sent driver update for driver_045
# [EventHub] Sent driver update for driver_046
# [EventHub] Sent driver update for driver_047
# [EventHub] Sent driver update for driver_048
# [EventHub] Sent driver update for driver_049
# [EventHub] Sent driver update for driver_050
# [EventHub] Sent driver update for driver_051
# [EventHub] Sent driver update for driver_052
# [EventHub] Sent driver update for driver_053
# [EventHub] Sent driver update for driver_054
# [EventHub] Sent driver update for driver_055
# [EventHub] Sent driver update for driver_056
# [EventHub] Sent driver update for driver_057
# [EventHub] Sent driver update for driver_058
# [EventHub] Sent driver update for driver_059
# [EventHub] Sent driver update for driver_060
# [EventHub] Sent driver update for driver_061
# [EventHub] Sent driver update for driver_062
# [EventHub] Sent driver update for driver_063
# [EventHub] Sent driver update for driver_064
# [EventHub] Sent driver update for driver_065
# [EventHub] Sent driver update for driver_066
# [EventHub] Sent driver update for driver_067
# [EventHub] Sent driver update for driver_068
# [EventHub] Sent driver update for driver_069
# [EventHub] Sent driver update for driver_070
# [EventHub] Sent driver update for driver_071
# [EventHub] Sent driver update for driver_072
# [EventHub] Sent driver update for driver_073
# [EventHub] Sent driver update for driver_074
# [EventHub] Sent driver update for driver_075
# [EventHub] Sent driver update for driver_076
# [EventHub] Sent driver update for driver_077
# [EventHub] Sent driver update for driver_078
# [EventHub] Sent driver update for driver_079
# [EventHub] Sent driver update for driver_080
# [EventHub] Sent driver update for driver_081
# [EventHub] Sent driver update for driver_082
# [EventHub] Sent driver update for driver_083
# [EventHub] Sent driver update for driver_084
# [EventHub] Sent driver update for driver_085
# [EventHub] Sent driver update for driver_086
# [EventHub] Sent driver update for driver_087
# [EventHub] Sent driver update for driver_088
# [EventHub] Sent driver update for driver_089
# [EventHub] Sent driver update for driver_090
# [EventHub] Sent driver update for driver_091
# [EventHub] Sent driver update for driver_092
# [EventHub] Sent driver update for driver_093
# [EventHub] Sent driver update for driver_094
# [EventHub] Sent driver update for driver_095
# [EventHub] Sent driver update for driver_096
# [EventHub] Sent driver update for driver_097
# [EventHub] Sent driver update for driver_098
# [EventHub] Sent driver update for driver_099
# [EventHub] Sent driver update for driver_100
# [EventHub] Sent driver update for driver_101
# [EventHub] Sent driver update for driver_102
# [EventHub] Sent driver update for driver_103
# [EventHub] Sent driver update for driver_104
# [EventHub] Sent driver update for driver_105
# [EventHub] Sent driver update for driver_106
# [EventHub] Sent driver update for driver_107
# [EventHub] Sent driver update for driver_108
# [EventHub] Sent driver update for driver_109
# [EventHub] Sent driver update for driver_110
# [EventHub] Sent driver update for driver_111
# [EventHub] Sent driver update for driver_112
# [EventHub] Sent driver update for driver_113
# [EventHub] Sent driver update for driver_114
# [EventHub] Sent driver update for driver_115
# [EventHub] Sent driver update for driver_116
# [EventHub] Sent driver update for driver_117
# [EventHub] Sent driver update for driver_118
# [EventHub] Sent driver update for driver_119
# [EventHub] Sent driver update for driver_120
# [EventHub] Sent driver update for driver_121
# [EventHub] Sent driver update for driver_122
# [EventHub] Sent driver update for driver_123
# [EventHub] Sent driver update for driver_124
# [EventHub] Sent driver update for driver_125
# [EventHub] Sent driver update for driver_126
# [EventHub] Sent driver update for driver_127
# [EventHub] Sent driver update for driver_128
# [EventHub] Sent driver update for driver_129
# [EventHub] Sent driver update for driver_130
# [EventHub] Sent driver update for driver_131
# [EventHub] Sent driver update for driver_132
# [EventHub] Sent driver update for driver_133
# [EventHub] Sent driver update for driver_134
# [EventHub] Sent driver update for driver_135
# [EventHub] Sent driver update for driver_136
# [EventHub] Sent driver update for driver_137
# [EventHub] Sent driver update for driver_138
# [EventHub] Sent driver update for driver_139
# [EventHub] Sent driver update for driver_140
# [EventHub] Sent driver update for driver_141
# [EventHub] Sent driver update for driver_142
# [EventHub] Sent driver update for driver_143
# [EventHub] Sent driver update for driver_144
# [EventHub] Sent driver update for driver_145
# [EventHub] Sent driver update for driver_146
# [EventHub] Sent driver update for driver_147
# [EventHub] Sent driver update for driver_148
# [EventHub] Sent driver update for driver_149
# [EventHub] Sent driver update for driver_150
# [EventHub] Sent driver update for driver_151
# [EventHub] Sent driver update for driver_152
# [EventHub] Sent driver update for driver_153
# [EventHub] Sent driver update for driver_154
# [EventHub] Sent driver update for driver_155
# [EventHub] Sent driver update for driver_156
# [EventHub] Sent driver update for driver_157
# [EventHub] Sent driver update for driver_158
# [EventHub] Sent driver update for driver_159
# [EventHub] Sent driver update for driver_160
# [EventHub] Sent driver update for driver_161
# [EventHub] Sent driver update for driver_162
# [EventHub] Sent driver update for driver_163
# [EventHub] Sent driver update for driver_164
# [EventHub] Sent driver update for driver_165
# [EventHub] Sent driver update for driver_166
# [EventHub] Sent driver update for driver_167
# [EventHub] Sent driver update for driver_168
# [EventHub] Sent driver update for driver_169
# [EventHub] Sent driver update for driver_170
# [EventHub] Sent driver update for driver_171
# [EventHub] Sent driver update for driver_172
# [EventHub] Sent driver update for driver_173
# [EventHub] Sent driver update for driver_174
# [EventHub] Sent driver update for driver_175
# [EventHub] Sent driver update for driver_176
# [EventHub] Sent driver update for driver_177
# [EventHub] Sent driver update for driver_178
# [EventHub] Sent driver update for driver_179
# [EventHub] Sent driver update for driver_180
# [EventHub] Sent driver update for driver_181
# [EventHub] Sent driver update for driver_182
# [EventHub] Sent driver update for driver_183
# [EventHub] Sent driver update for driver_184
# [EventHub] Sent driver update for driver_185
# [EventHub] Sent driver update for driver_186
# [EventHub] Sent driver update for driver_187
# [EventHub] Sent driver update for driver_188
# [EventHub] Sent driver update for driver_189
# [EventHub] Sent driver update for driver_190
# [EventHub] Sent driver update for driver_191
# [EventHub] Sent driver update for driver_192
# [EventHub] Sent driver update for driver_193
# [EventHub] Sent driver update for driver_194
# [EventHub] Sent driver update for driver_195
# [EventHub] Sent driver update for driver_196
# [EventHub] Sent driver update for driver_197
# [EventHub] Sent driver update for driver_198
# [EventHub] Sent driver update for driver_199
# [EventHub] Sent driver update for driver_200
# [EventHub] Sent driver update for driver_201
# [EventHub] Sent driver update for driver_202
# [EventHub] Sent driver update for driver_203
# [EventHub] Sent driver update for driver_204
# [EventHub] Sent driver update for driver_205
# [EventHub] Sent driver update for driver_206
# [EventHub] Sent driver update for driver_207
# [EventHub] Sent driver update for driver_208
# [EventHub] Sent driver update for driver_209
# [EventHub] Sent driver update for driver_210
# [EventHub] Sent driver update for driver_211
# [EventHub] Sent driver update for driver_212
# [EventHub] Sent driver update for driver_213
# [EventHub] Sent driver update for driver_214
# [EventHub] Sent driver update for driver_215
# [EventHub] Sent driver update for driver_216
# [EventHub] Sent driver update for driver_217
# [EventHub] Sent driver update for driver_218
# [EventHub] Sent driver update for driver_219
# [EventHub] Sent driver update for driver_220
# [EventHub] Sent driver update for driver_221
# [EventHub] Sent driver update for driver_222
# [EventHub] Sent driver update for driver_223
# [EventHub] Sent driver update for driver_224
# [EventHub] Sent driver update for driver_225
# [EventHub] Sent driver update for driver_226
# [EventHub] Sent driver update for driver_227
# [EventHub] Sent driver update for driver_228
# [EventHub] Sent driver update for driver_229
# [EventHub] Sent driver update for driver_230
# [EventHub] Sent driver update for driver_231
# [EventHub] Sent driver update for driver_232
# [EventHub] Sent driver update for driver_233
# [EventHub] Sent driver update for driver_234
# [EventHub] Sent driver update for driver_235
# [EventHub] Sent driver update for driver_236
# [EventHub] Sent driver update for driver_237
# [EventHub] Sent driver update for driver_238
# [EventHub] Sent driver update for driver_239
# [EventHub] Sent driver update for driver_240
# [EventHub] Sent driver update for driver_241
# [EventHub] Sent driver update for driver_242
# [EventHub] Sent driver update for driver_243
# [EventHub] Sent driver update for driver_244
# [EventHub] Sent driver update for driver_245
# [EventHub] Sent driver update for driver_246
# [EventHub] Sent driver update for driver_247
# [EventHub] Sent driver update for driver_248
# [EventHub] Sent driver update for driver_249
# [EventHub] Sent driver update for driver_250
# [EventHub] Sent driver update for driver_251
# [EventHub] Sent driver update for driver_252
# [EventHub] Sent driver update for driver_253
# [EventHub] Sent driver update for driver_254
# [EventHub] Sent driver update for driver_255
# [EventHub] Sent driver update for driver_256
# [EventHub] Sent driver update for driver_257
# [EventHub] Sent driver update for driver_258
# [EventHub] Sent driver update for driver_259
# [EventHub] Sent driver update for driver_260
# [EventHub] Sent driver update for driver_261
# [EventHub] Sent driver update for driver_262
# [EventHub] Sent driver update for driver_263
# [EventHub] Sent driver update for driver_264
# [EventHub] Sent driver update for driver_265
# [EventHub] Sent driver update for driver_266
# [EventHub] Sent driver update for driver_267
# [EventHub] Sent driver update for driver_268
# [EventHub] Sent driver update for driver_269
# [EventHub] Sent driver update for driver_270
# [EventHub] Sent driver update for driver_271
# [EventHub] Sent driver update for driver_272
# [EventHub] Sent driver update for driver_273
# [EventHub] Sent driver update for driver_274
# [EventHub] Sent driver update for driver_275
# [EventHub] Sent driver update for driver_276
# [EventHub] Sent driver update for driver_277
# [EventHub] Sent driver update for driver_278
# [EventHub] Sent driver update for driver_279
# [EventHub] Sent driver update for driver_280
# [EventHub] Sent driver update for driver_281
# [EventHub] Sent driver update for driver_282
# [EventHub] Sent driver update for driver_283
# [EventHub] Sent driver update for driver_284
# [EventHub] Sent driver update for driver_285
# [EventHub] Sent driver update for driver_286
# [EventHub] Sent driver update for driver_287
# [EventHub] Sent driver update for driver_288
# [EventHub] Sent driver update for driver_289
# [EventHub] Sent driver update for driver_290
# [EventHub] Sent driver update for driver_291
# [EventHub] Sent driver update for driver_292
# [EventHub] Sent driver update for driver_293
# [EventHub] Sent driver update for driver_294
# [EventHub] Sent driver update for driver_295
# [EventHub] Sent driver update for driver_296
# [EventHub] Sent driver update for driver_297
# [EventHub] Sent driver update for driver_298
# [EventHub] Sent driver update for driver_299
# [New Requests] Generating 0 ride request(s) this cycle.
# [Pickup Complete] driver_005 has reached the pickup location.
# [Trip Details] Distance: 19.42 km, Trip Time: 2329.82 sec, Estimated Fare: 126.49.
#
# [Simulation Time] Minute 272
# [Demand Update] Time: 04:00, Poisson Demand: 3, Demand Multiplier: 1.00, Pricing Multiplier: 1.00, Speed Factor: 1.00, Base Lambda: 3
# [Driver Workforce] driver_008 went OFFLINE.
# [Driver Workforce] driver_085 went OFFLINE.
# [Driver Workforce] driver_103 came ONLINE.
# [Driver Workforce] driver_145 went OFFLINE.
# [Snapshot] 44/300 drivers working.
# Delivered to group3-driver-updates [0] offset 670761
# Delivered to group3-driver-updates [0] offset 670762
# Delivered to group3-driver-updates [0] offset 670763
# Delivered to group3-driver-updates [0] offset 670764
# Delivered to group3-driver-updates [0] offset 670765
# Delivered to group3-driver-updates [0] offset 670766
# Delivered to group3-driver-updates [0] offset 670767
# Delivered to group3-driver-updates [0] offset 670768
# Delivered to group3-driver-updates [0] offset 670769
# Delivered to group3-driver-updates [0] offset 670770
# Delivered to group3-driver-updates [0] offset 670771
# Delivered to group3-driver-updates [0] offset 670772
# Delivered to group3-driver-updates [0] offset 670773
# Delivered to group3-driver-updates [0] offset 670774
# Delivered to group3-driver-updates [0] offset 670775
# Delivered to group3-driver-updates [0] offset 670776
# Delivered to group3-driver-updates [0] offset 670777
# Delivered to group3-driver-updates [0] offset 670778
# Delivered to group3-driver-updates [0] offset 670779
# Delivered to group3-driver-updates [0] offset 670780
# Delivered to group3-driver-updates [0] offset 670781
# Delivered to group3-driver-updates [0] offset 670782
# Delivered to group3-driver-updates [0] offset 670783
# Delivered to group3-driver-updates [0] offset 670784
# Delivered to group3-driver-updates [0] offset 670785
# Delivered to group3-driver-updates [0] offset 670786
# Delivered to group3-driver-updates [0] offset 670787
# Delivered to group3-driver-updates [0] offset 670788
# Delivered to group3-driver-updates [0] offset 670789
# Delivered to group3-driver-updates [0] offset 670790
# Delivered to group3-driver-updates [0] offset 670791
# Delivered to group3-driver-updates [0] offset 670792
# Delivered to group3-driver-updates [0] offset 670793
# Delivered to group3-driver-updates [0] offset 670794
# Delivered to group3-driver-updates [0] offset 670795
# Delivered to group3-driver-updates [0] offset 670796
# Delivered to group3-driver-updates [0] offset 670797
# Delivered to group3-driver-updates [0] offset 670798
# Delivered to group3-driver-updates [0] offset 670799
# Delivered to group3-driver-updates [0] offset 670800
# Delivered to group3-driver-updates [0] offset 670801
# Delivered to group3-driver-updates [0] offset 670802
# Delivered to group3-driver-updates [0] offset 670803
# Delivered to group3-driver-updates [0] offset 670804
# Delivered to group3-driver-updates [0] offset 670805
# Delivered to group3-driver-updates [0] offset 670806
# Delivered to group3-driver-updates [0] offset 670807
# Delivered to group3-driver-updates [0] offset 670808
# Delivered to group3-driver-updates [0] offset 670809
# Delivered to group3-driver-updates [0] offset 670810
# Delivered to group3-driver-updates [0] offset 670811
# Delivered to group3-driver-updates [0] offset 670812
# Delivered to group3-driver-updates [0] offset 670813
# Delivered to group3-driver-updates [0] offset 670814
# Delivered to group3-driver-updates [0] offset 670815
# Delivered to group3-driver-updates [0] offset 670816
# Delivered to group3-driver-updates [0] offset 670817
# Delivered to group3-driver-updates [0] offset 670818
# Delivered to group3-driver-updates [0] offset 670819
# Delivered to group3-driver-updates [0] offset 670820
# Delivered to group3-driver-updates [0] offset 670821
# Delivered to group3-driver-updates [0] offset 670822
# Delivered to group3-driver-updates [0] offset 670823
# Delivered to group3-driver-updates [0] offset 670824
# Delivered to group3-driver-updates [0] offset 670825
# Delivered to group3-driver-updates [0] offset 670826
# Delivered to group3-driver-updates [0] offset 670827
# Delivered to group3-driver-updates [0] offset 670828
# Delivered to group3-driver-updates [0] offset 670829
# Delivered to group3-driver-updates [0] offset 670830
# Delivered to group3-driver-updates [0] offset 670831
# Delivered to group3-driver-updates [0] offset 670832
# Delivered to group3-driver-updates [0] offset 670833
# Delivered to group3-driver-updates [0] offset 670834
# Delivered to group3-driver-updates [0] offset 670835
# Delivered to group3-driver-updates [0] offset 670836
# Delivered to group3-driver-updates [0] offset 670837
# Delivered to group3-driver-updates [0] offset 670838
# Delivered to group3-driver-updates [0] offset 670839
# Delivered to group3-driver-updates [0] offset 670840
# Delivered to group3-driver-updates [0] offset 670841
# Delivered to group3-driver-updates [0] offset 670842
# Delivered to group3-driver-updates [0] offset 670843
# Delivered to group3-driver-updates [0] offset 670844
# Delivered to group3-driver-updates [0] offset 670845
# Delivered to group3-driver-updates [0] offset 670846
# Delivered to group3-driver-updates [0] offset 670847
# Delivered to group3-driver-updates [0] offset 670848
# Delivered to group3-driver-updates [0] offset 670849
# Delivered to group3-driver-updates [0] offset 670850
# Delivered to group3-driver-updates [0] offset 670851
# Delivered to group3-driver-updates [0] offset 670852
# Delivered to group3-driver-updates [0] offset 670853
# Delivered to group3-driver-updates [0] offset 670854
# Delivered to group3-driver-updates [0] offset 670855
# Delivered to group3-driver-updates [0] offset 670856
# Delivered to group3-driver-updates [0] offset 670857
# Delivered to group3-driver-updates [0] offset 670858
# Delivered to group3-driver-updates [0] offset 670859
# Delivered to group3-driver-updates [0] offset 670860
# Delivered to group3-driver-updates [0] offset 670861
# Delivered to group3-driver-updates [0] offset 670862
# Delivered to group3-driver-updates [0] offset 670863
# Delivered to group3-driver-updates [0] offset 670864
# Delivered to group3-driver-updates [0] offset 670865
# Delivered to group3-driver-updates [0] offset 670866
# Delivered to group3-driver-updates [0] offset 670867
# Delivered to group3-driver-updates [0] offset 670868
# Delivered to group3-driver-updates [0] offset 670869
# Delivered to group3-driver-updates [0] offset 670870
# Delivered to group3-driver-updates [0] offset 670871
# Delivered to group3-driver-updates [0] offset 670872
# Delivered to group3-driver-updates [0] offset 670873
# Delivered to group3-driver-updates [0] offset 670874
# Delivered to group3-driver-updates [0] offset 670875
# Delivered to group3-driver-updates [0] offset 670876
# Delivered to group3-driver-updates [0] offset 670877
# Delivered to group3-driver-updates [0] offset 670878
# Delivered to group3-driver-updates [0] offset 670879
# Delivered to group3-driver-updates [0] offset 670880
# Delivered to group3-driver-updates [0] offset 670881
# Delivered to group3-driver-updates [0] offset 670882
# Delivered to group3-driver-updates [0] offset 670883
# Delivered to group3-driver-updates [0] offset 670884
# Delivered to group3-driver-updates [0] offset 670885
# Delivered to group3-driver-updates [0] offset 670886
# Delivered to group3-driver-updates [0] offset 670887
# Delivered to group3-driver-updates [0] offset 670888
# Delivered to group3-driver-updates [0] offset 670889
# Delivered to group3-driver-updates [0] offset 670890
# Delivered to group3-driver-updates [0] offset 670891
# Delivered to group3-driver-updates [0] offset 670892
# Delivered to group3-driver-updates [0] offset 670893
# Delivered to group3-driver-updates [0] offset 670894
# Delivered to group3-driver-updates [0] offset 670895
# Delivered to group3-driver-updates [0] offset 670896
# Delivered to group3-driver-updates [0] offset 670897
# Delivered to group3-driver-updates [0] offset 670898
# Delivered to group3-driver-updates [0] offset 670899
# Delivered to group3-driver-updates [0] offset 670900
# Delivered to group3-driver-updates [0] offset 670901
# Delivered to group3-driver-updates [0] offset 670902
# Delivered to group3-driver-updates [0] offset 670903
# Delivered to group3-driver-updates [0] offset 670904
# Delivered to group3-driver-updates [0] offset 670905
# Delivered to group3-driver-updates [0] offset 670906
# Delivered to group3-driver-updates [0] offset 670907
# Delivered to group3-driver-updates [0] offset 670908
# Delivered to group3-driver-updates [0] offset 670909
# Delivered to group3-driver-updates [0] offset 670910
# Delivered to group3-driver-updates [0] offset 670911
# Delivered to group3-driver-updates [0] offset 670912
# Delivered to group3-driver-updates [0] offset 670913
# Delivered to group3-driver-updates [0] offset 670914
# Delivered to group3-driver-updates [0] offset 670915
# Delivered to group3-driver-updates [0] offset 670916
# Delivered to group3-driver-updates [0] offset 670917
# Delivered to group3-driver-updates [0] offset 670918
# Delivered to group3-driver-updates [0] offset 670919
# Delivered to group3-driver-updates [0] offset 670920
# Delivered to group3-driver-updates [0] offset 670921
# Delivered to group3-driver-updates [0] offset 670922
# Delivered to group3-driver-updates [0] offset 670923
# Delivered to group3-driver-updates [0] offset 670924
# Delivered to group3-driver-updates [0] offset 670925
# Delivered to group3-driver-updates [0] offset 670926
# Delivered to group3-driver-updates [0] offset 670927
# Delivered to group3-driver-updates [0] offset 670928
# Delivered to group3-driver-updates [0] offset 670929
# Delivered to group3-driver-updates [0] offset 670930
# Delivered to group3-driver-updates [0] offset 670931
# Delivered to group3-driver-updates [0] offset 670932
# Delivered to group3-driver-updates [0] offset 670933
# Delivered to group3-driver-updates [0] offset 670934
# Delivered to group3-driver-updates [0] offset 670935
# Delivered to group3-driver-updates [0] offset 670936
# Delivered to group3-driver-updates [0] offset 670937
# Delivered to group3-driver-updates [0] offset 670938
# Delivered to group3-driver-updates [0] offset 670939
# Delivered to group3-driver-updates [0] offset 670940
# Delivered to group3-driver-updates [0] offset 670941
# Delivered to group3-driver-updates [0] offset 670942
# Delivered to group3-driver-updates [0] offset 670943
# Delivered to group3-driver-updates [0] offset 670944
# Delivered to group3-driver-updates [0] offset 670945
# Delivered to group3-driver-updates [0] offset 670946
# Delivered to group3-driver-updates [0] offset 670947
# Delivered to group3-driver-updates [0] offset 670948
# Delivered to group3-driver-updates [0] offset 670949
# Delivered to group3-driver-updates [0] offset 670950
# Delivered to group3-driver-updates [0] offset 670951
# Delivered to group3-driver-updates [0] offset 670952
# Delivered to group3-driver-updates [0] offset 670953
# Delivered to group3-driver-updates [0] offset 670954
# Delivered to group3-driver-updates [0] offset 670955
# Delivered to group3-driver-updates [0] offset 670956
# Delivered to group3-driver-updates [0] offset 670957
# Delivered to group3-driver-updates [0] offset 670958
# Delivered to group3-driver-updates [0] offset 670959
# Delivered to group3-driver-updates [0] offset 670960
# Delivered to group3-driver-updates [0] offset 670961
# Delivered to group3-driver-updates [0] offset 670962
# Delivered to group3-driver-updates [0] offset 670963
# Delivered to group3-driver-updates [0] offset 670964
# Delivered to group3-driver-updates [0] offset 670965
# Delivered to group3-driver-updates [0] offset 670966
# Delivered to group3-driver-updates [0] offset 670967
# Delivered to group3-driver-updates [0] offset 670968
# Delivered to group3-driver-updates [0] offset 670969
# Delivered to group3-driver-updates [0] offset 670970
# Delivered to group3-driver-updates [0] offset 670971
# Delivered to group3-driver-updates [0] offset 670972
# Delivered to group3-driver-updates [0] offset 670973
# Delivered to group3-driver-updates [0] offset 670974
# Delivered to group3-driver-updates [0] offset 670975
# Delivered to group3-driver-updates [0] offset 670976
# Delivered to group3-driver-updates [0] offset 670977
# Delivered to group3-driver-updates [0] offset 670978
# Delivered to group3-driver-updates [0] offset 670979
# Delivered to group3-driver-updates [0] offset 670980
# Delivered to group3-driver-updates [0] offset 670981
# Delivered to group3-driver-updates [0] offset 670982
# Delivered to group3-driver-updates [0] offset 670983
# Delivered to group3-driver-updates [0] offset 670984
# Delivered to group3-driver-updates [0] offset 670985
# Delivered to group3-driver-updates [0] offset 670986
# Delivered to group3-driver-updates [0] offset 670987
# Delivered to group3-driver-updates [0] offset 670988
# Delivered to group3-driver-updates [0] offset 670989
# Delivered to group3-driver-updates [0] offset 670990
# Delivered to group3-driver-updates [0] offset 670991
# Delivered to group3-driver-updates [0] offset 670992
# Delivered to group3-driver-updates [0] offset 670993
# Delivered to group3-driver-updates [0] offset 670994
# Delivered to group3-driver-updates [0] offset 670995
# Delivered to group3-driver-updates [0] offset 670996
# Delivered to group3-driver-updates [0] offset 670997
# Delivered to group3-driver-updates [0] offset 670998
# Delivered to group3-driver-updates [0] offset 670999
# Delivered to group3-driver-updates [0] offset 671000
# Delivered to group3-driver-updates [0] offset 671001
# Delivered to group3-driver-updates [0] offset 671002
# Delivered to group3-driver-updates [0] offset 671003
# Delivered to group3-driver-updates [0] offset 671004
# Delivered to group3-driver-updates [0] offset 671005
# Delivered to group3-driver-updates [0] offset 671006
# Delivered to group3-driver-updates [0] offset 671007
# Delivered to group3-driver-updates [0] offset 671008
# Delivered to group3-driver-updates [0] offset 671009
# Delivered to group3-driver-updates [0] offset 671010
# Delivered to group3-driver-updates [0] offset 671011
# Delivered to group3-driver-updates [0] offset 671012
# Delivered to group3-driver-updates [0] offset 671013
# Delivered to group3-driver-updates [0] offset 671014
# Delivered to group3-driver-updates [0] offset 671015
# Delivered to group3-driver-updates [0] offset 671016
# Delivered to group3-driver-updates [0] offset 671017
# Delivered to group3-driver-updates [0] offset 671018
# Delivered to group3-driver-updates [0] offset 671019
# Delivered to group3-driver-updates [0] offset 671020
# Delivered to group3-driver-updates [0] offset 671021
# Delivered to group3-driver-updates [0] offset 671022
# Delivered to group3-driver-updates [0] offset 671023
# Delivered to group3-driver-updates [0] offset 671024
# Delivered to group3-driver-updates [0] offset 671025
# Delivered to group3-driver-updates [0] offset 671026
# Delivered to group3-driver-updates [0] offset 671027
# Delivered to group3-driver-updates [0] offset 671028
# Delivered to group3-driver-updates [0] offset 671029
# Delivered to group3-driver-updates [0] offset 671030
# Delivered to group3-driver-updates [0] offset 671031
# Delivered to group3-driver-updates [0] offset 671032
# Delivered to group3-driver-updates [0] offset 671033
# Delivered to group3-driver-updates [0] offset 671034
# Delivered to group3-driver-updates [0] offset 671035
# Delivered to group3-driver-updates [0] offset 671036
# Delivered to group3-driver-updates [0] offset 671037
# Delivered to group3-driver-updates [0] offset 671038
# Delivered to group3-driver-updates [0] offset 671039
# Delivered to group3-driver-updates [0] offset 671040
# Delivered to group3-driver-updates [0] offset 671041
# Delivered to group3-driver-updates [0] offset 671042
# Delivered to group3-driver-updates [0] offset 671043
# Delivered to group3-driver-updates [0] offset 671044
# Delivered to group3-driver-updates [0] offset 671045
# Delivered to group3-driver-updates [0] offset 671046
# Delivered to group3-driver-updates [0] offset 671047
# Delivered to group3-driver-updates [0] offset 671048
# Delivered to group3-driver-updates [0] offset 671049
# Delivered to group3-driver-updates [0] offset 671050
# Delivered to group3-driver-updates [0] offset 671051
# Delivered to group3-driver-updates [0] offset 671052
# Delivered to group3-driver-updates [0] offset 671053
# Delivered to group3-driver-updates [0] offset 671054
# Delivered to group3-driver-updates [0] offset 671055
# Delivered to group3-driver-updates [0] offset 671056
# Delivered to group3-driver-updates [0] offset 671057
# Delivered to group3-driver-updates [0] offset 671058
# Delivered to group3-driver-updates [0] offset 671059
# Delivered to group3-driver-updates [0] offset 671060
# [EventHub] Sent driver update for driver_000
# [EventHub] Sent driver update for driver_001
# [EventHub] Sent driver update for driver_002
# [EventHub] Sent driver update for driver_003
# [EventHub] Sent driver update for driver_004
# [EventHub] Sent driver update for driver_005
# [EventHub] Sent driver update for driver_006
# [EventHub] Sent driver update for driver_007
# [EventHub] Sent driver update for driver_008
# [EventHub] Sent driver update for driver_009
# [EventHub] Sent driver update for driver_010
# [EventHub] Sent driver update for driver_011
# [EventHub] Sent driver update for driver_012
# [EventHub] Sent driver update for driver_013
# [EventHub] Sent driver update for driver_014
# [EventHub] Sent driver update for driver_015
# [EventHub] Sent driver update for driver_016
# [EventHub] Sent driver update for driver_017
# [EventHub] Sent driver update for driver_018
# [EventHub] Sent driver update for driver_019
# [EventHub] Sent driver update for driver_020
# [EventHub] Sent driver update for driver_021
# [EventHub] Sent driver update for driver_022
# [EventHub] Sent driver update for driver_023
# [EventHub] Sent driver update for driver_024
# [EventHub] Sent driver update for driver_025
# [EventHub] Sent driver update for driver_026
# [EventHub] Sent driver update for driver_027
# [EventHub] Sent driver update for driver_028
# [EventHub] Sent driver update for driver_029
# [EventHub] Sent driver update for driver_030
# [EventHub] Sent driver update for driver_031
# [EventHub] Sent driver update for driver_032
# [EventHub] Sent driver update for driver_033
# [EventHub] Sent driver update for driver_034
# [EventHub] Sent driver update for driver_035
# [EventHub] Sent driver update for driver_036
# [EventHub] Sent driver update for driver_037
# [EventHub] Sent driver update for driver_038
# [EventHub] Sent driver update for driver_039
# [EventHub] Sent driver update for driver_040
# [EventHub] Sent driver update for driver_041
# [EventHub] Sent driver update for driver_042
# [EventHub] Sent driver update for driver_043
# [EventHub] Sent driver update for driver_044
# [EventHub] Sent driver update for driver_045
# [EventHub] Sent driver update for driver_046
# [EventHub] Sent driver update for driver_047
# [EventHub] Sent driver update for driver_048
# [EventHub] Sent driver update for driver_049
# [EventHub] Sent driver update for driver_050
# [EventHub] Sent driver update for driver_051
# [EventHub] Sent driver update for driver_052
# [EventHub] Sent driver update for driver_053
# [EventHub] Sent driver update for driver_054
# [EventHub] Sent driver update for driver_055
# [EventHub] Sent driver update for driver_056
# [EventHub] Sent driver update for driver_057
# [EventHub] Sent driver update for driver_058
# [EventHub] Sent driver update for driver_059
# [EventHub] Sent driver update for driver_060
# [EventHub] Sent driver update for driver_061
# [EventHub] Sent driver update for driver_062
# [EventHub] Sent driver update for driver_063
# [EventHub] Sent driver update for driver_064
# [EventHub] Sent driver update for driver_065
# [EventHub] Sent driver update for driver_066
# [EventHub] Sent driver update for driver_067
# [EventHub] Sent driver update for driver_068
# [EventHub] Sent driver update for driver_069
# [EventHub] Sent driver update for driver_070
# [EventHub] Sent driver update for driver_071
# [EventHub] Sent driver update for driver_072
# [EventHub] Sent driver update for driver_073
# [EventHub] Sent driver update for driver_074
# [EventHub] Sent driver update for driver_075
# [EventHub] Sent driver update for driver_076
# [EventHub] Sent driver update for driver_077
# [EventHub] Sent driver update for driver_078
# [EventHub] Sent driver update for driver_079
# [EventHub] Sent driver update for driver_080
# [EventHub] Sent driver update for driver_081
# [EventHub] Sent driver update for driver_082
# [EventHub] Sent driver update for driver_083
# [EventHub] Sent driver update for driver_084
# [EventHub] Sent driver update for driver_085
# [EventHub] Sent driver update for driver_086
# [EventHub] Sent driver update for driver_087
# [EventHub] Sent driver update for driver_088
# [EventHub] Sent driver update for driver_089
# [EventHub] Sent driver update for driver_090
# [EventHub] Sent driver update for driver_091
# [EventHub] Sent driver update for driver_092
# [EventHub] Sent driver update for driver_093
# [EventHub] Sent driver update for driver_094
# [EventHub] Sent driver update for driver_095
# [EventHub] Sent driver update for driver_096
# [EventHub] Sent driver update for driver_097
# [EventHub] Sent driver update for driver_098
# [EventHub] Sent driver update for driver_099
# [EventHub] Sent driver update for driver_100
# [EventHub] Sent driver update for driver_101
# [EventHub] Sent driver update for driver_102
# [EventHub] Sent driver update for driver_103
# [EventHub] Sent driver update for driver_104
# [EventHub] Sent driver update for driver_105
# [EventHub] Sent driver update for driver_106
# [EventHub] Sent driver update for driver_107
# [EventHub] Sent driver update for driver_108
# [EventHub] Sent driver update for driver_109
# [EventHub] Sent driver update for driver_110
# [EventHub] Sent driver update for driver_111
# [EventHub] Sent driver update for driver_112
# [EventHub] Sent driver update for driver_113
# [EventHub] Sent driver update for driver_114
# [EventHub] Sent driver update for driver_115
# [EventHub] Sent driver update for driver_116
# [EventHub] Sent driver update for driver_117
# [EventHub] Sent driver update for driver_118
# [EventHub] Sent driver update for driver_119
# [EventHub] Sent driver update for driver_120
# [EventHub] Sent driver update for driver_121
# [EventHub] Sent driver update for driver_122
# [EventHub] Sent driver update for driver_123
# [EventHub] Sent driver update for driver_124
# [EventHub] Sent driver update for driver_125
# [EventHub] Sent driver update for driver_126
# [EventHub] Sent driver update for driver_127
# [EventHub] Sent driver update for driver_128
# [EventHub] Sent driver update for driver_129
# [EventHub] Sent driver update for driver_130
# [EventHub] Sent driver update for driver_131
# [EventHub] Sent driver update for driver_132
# [EventHub] Sent driver update for driver_133
# [EventHub] Sent driver update for driver_134
# [EventHub] Sent driver update for driver_135
# [EventHub] Sent driver update for driver_136
# [EventHub] Sent driver update for driver_137
# [EventHub] Sent driver update for driver_138
# [EventHub] Sent driver update for driver_139
# [EventHub] Sent driver update for driver_140
# [EventHub] Sent driver update for driver_141
# [EventHub] Sent driver update for driver_142
# [EventHub] Sent driver update for driver_143
# [EventHub] Sent driver update for driver_144
# [EventHub] Sent driver update for driver_145
# [EventHub] Sent driver update for driver_146
# [EventHub] Sent driver update for driver_147
# [EventHub] Sent driver update for driver_148
# [EventHub] Sent driver update for driver_149
# [EventHub] Sent driver update for driver_150
# [EventHub] Sent driver update for driver_151
# [EventHub] Sent driver update for driver_152
# [EventHub] Sent driver update for driver_153
# [EventHub] Sent driver update for driver_154
# [EventHub] Sent driver update for driver_155
# [EventHub] Sent driver update for driver_156
# [EventHub] Sent driver update for driver_157
# [EventHub] Sent driver update for driver_158
# [EventHub] Sent driver update for driver_159
# [EventHub] Sent driver update for driver_160
# [EventHub] Sent driver update for driver_161
# [EventHub] Sent driver update for driver_162
# [EventHub] Sent driver update for driver_163
# [EventHub] Sent driver update for driver_164
# [EventHub] Sent driver update for driver_165
# [EventHub] Sent driver update for driver_166
# [EventHub] Sent driver update for driver_167
# [EventHub] Sent driver update for driver_168
# [EventHub] Sent driver update for driver_169
# [EventHub] Sent driver update for driver_170
# [EventHub] Sent driver update for driver_171
# [EventHub] Sent driver update for driver_172
# [EventHub] Sent driver update for driver_173
# [EventHub] Sent driver update for driver_174
# [EventHub] Sent driver update for driver_175
# [EventHub] Sent driver update for driver_176
# [EventHub] Sent driver update for driver_177
# [EventHub] Sent driver update for driver_178
# [EventHub] Sent driver update for driver_179
# [EventHub] Sent driver update for driver_180
# [EventHub] Sent driver update for driver_181
# [EventHub] Sent driver update for driver_182
# [EventHub] Sent driver update for driver_183
# [EventHub] Sent driver update for driver_184
# [EventHub] Sent driver update for driver_185
# [EventHub] Sent driver update for driver_186
# [EventHub] Sent driver update for driver_187
# [EventHub] Sent driver update for driver_188
# [EventHub] Sent driver update for driver_189
# [EventHub] Sent driver update for driver_190
# [EventHub] Sent driver update for driver_191
# [EventHub] Sent driver update for driver_192
# [EventHub] Sent driver update for driver_193
# [EventHub] Sent driver update for driver_194
# [EventHub] Sent driver update for driver_195
# [EventHub] Sent driver update for driver_196
# [EventHub] Sent driver update for driver_197
# [EventHub] Sent driver update for driver_198
# [EventHub] Sent driver update for driver_199
# [EventHub] Sent driver update for driver_200
# [EventHub] Sent driver update for driver_201
# [EventHub] Sent driver update for driver_202
# [EventHub] Sent driver update for driver_203
# [EventHub] Sent driver update for driver_204
# [EventHub] Sent driver update for driver_205
# [EventHub] Sent driver update for driver_206
# [EventHub] Sent driver update for driver_207
# [EventHub] Sent driver update for driver_208
# [EventHub] Sent driver update for driver_209
# [EventHub] Sent driver update for driver_210
# [EventHub] Sent driver update for driver_211
# [EventHub] Sent driver update for driver_212
# [EventHub] Sent driver update for driver_213
# [EventHub] Sent driver update for driver_214
# [EventHub] Sent driver update for driver_215
# [EventHub] Sent driver update for driver_216
# [EventHub] Sent driver update for driver_217
# [EventHub] Sent driver update for driver_218
# [EventHub] Sent driver update for driver_219
# [EventHub] Sent driver update for driver_220
# [EventHub] Sent driver update for driver_221
# [EventHub] Sent driver update for driver_222
# [EventHub] Sent driver update for driver_223
# [EventHub] Sent driver update for driver_224
# [EventHub] Sent driver update for driver_225
# [EventHub] Sent driver update for driver_226
# [EventHub] Sent driver update for driver_227
# [EventHub] Sent driver update for driver_228
# [EventHub] Sent driver update for driver_229
# [EventHub] Sent driver update for driver_230
# [EventHub] Sent driver update for driver_231
# [EventHub] Sent driver update for driver_232
# [EventHub] Sent driver update for driver_233
# [EventHub] Sent driver update for driver_234
# [EventHub] Sent driver update for driver_235
# [EventHub] Sent driver update for driver_236
# [EventHub] Sent driver update for driver_237
# [EventHub] Sent driver update for driver_238
# [EventHub] Sent driver update for driver_239
# [EventHub] Sent driver update for driver_240
# [EventHub] Sent driver update for driver_241
# [EventHub] Sent driver update for driver_242
# [EventHub] Sent driver update for driver_243
# [EventHub] Sent driver update for driver_244
# [EventHub] Sent driver update for driver_245
# [EventHub] Sent driver update for driver_246
# [EventHub] Sent driver update for driver_247
# [EventHub] Sent driver update for driver_248
# [EventHub] Sent driver update for driver_249
# [EventHub] Sent driver update for driver_250
# [EventHub] Sent driver update for driver_251
# [EventHub] Sent driver update for driver_252
# [EventHub] Sent driver update for driver_253
# [EventHub] Sent driver update for driver_254
# [EventHub] Sent driver update for driver_255
# [EventHub] Sent driver update for driver_256
# [EventHub] Sent driver update for driver_257
# [EventHub] Sent driver update for driver_258
# [EventHub] Sent driver update for driver_259
# [EventHub] Sent driver update for driver_260
# [EventHub] Sent driver update for driver_261
# [EventHub] Sent driver update for driver_262
# [EventHub] Sent driver update for driver_263
# [EventHub] Sent driver update for driver_264
# [EventHub] Sent driver update for driver_265
# [EventHub] Sent driver update for driver_266
# [EventHub] Sent driver update for driver_267
# [EventHub] Sent driver update for driver_268
# [EventHub] Sent driver update for driver_269
# [EventHub] Sent driver update for driver_270
# [EventHub] Sent driver update for driver_271
# [EventHub] Sent driver update for driver_272
# [EventHub] Sent driver update for driver_273
# [EventHub] Sent driver update for driver_274
# [EventHub] Sent driver update for driver_275
# [EventHub] Sent driver update for driver_276
# [EventHub] Sent driver update for driver_277
# [EventHub] Sent driver update for driver_278
# [EventHub] Sent driver update for driver_279
# [EventHub] Sent driver update for driver_280
# [EventHub] Sent driver update for driver_281
# [EventHub] Sent driver update for driver_282
# [EventHub] Sent driver update for driver_283
# [EventHub] Sent driver update for driver_284
# [EventHub] Sent driver update for driver_285
# [EventHub] Sent driver update for driver_286
# [EventHub] Sent driver update for driver_287
# [EventHub] Sent driver update for driver_288
# [EventHub] Sent driver update for driver_289
# [EventHub] Sent driver update for driver_290
# [EventHub] Sent driver update for driver_291
# [EventHub] Sent driver update for driver_292
# [EventHub] Sent driver update for driver_293
# [EventHub] Sent driver update for driver_294
# [EventHub] Sent driver update for driver_295
# [EventHub] Sent driver update for driver_296
# [EventHub] Sent driver update for driver_297
# [EventHub] Sent driver update for driver_298
# [EventHub] Sent driver update for driver_299
# [New Requests] Generating 2 ride request(s) this cycle.
# [Make Request] Passenger P00002 created request REQ-1745433110-5224.
# [New Request] REQ-1745433110-5224 generated by passenger P00002.
# [Process Request] Received ride request REQ-1745433110-5224 from passenger P00002.
# [Demand Update] Time: 04:00, Poisson Demand: 5, Demand Multiplier: 1.67, Pricing Multiplier: 1.67, Speed Factor: 1.00, Base Lambda: 3
# [Driver Assigned] driver_294 with ECONOMY assigned for pickup at (40.62499575186184, -73.84989288691561).
# [Ride Start] driver_294 is heading to pickup location {'latitude': 40.62499575186184, 'longitude': -73.84989288691561} for passenger P00002.
# [Pickup] driver_294 is 5.29 km away; estimated time: 634.50 sec.
# [Make Request] Passenger P00596 created request REQ-1745433110-9485.
# [New Request] REQ-1745433110-9485 generated by passenger P00596.
# ...
# Delivered to group3-driver-updates [0] offset 672867
# Delivered to group3-driver-updates [0] offset 672868
# Delivered to group3-driver-updates [0] offset 672869
# Delivered to group3-driver-updates [0] offset 672870
# Delivered to group3-driver-updates [0] offset 672871
# Delivered to group3-driver-updates [0] offset 672872
# Delivered to group3-driver-updates [0] offset 672873
# Delivered to group3-driver-updates [0] offset 672874
# Delivered to group3-driver-updates [0] offset 672875
# Delivered to group3-driver-updates [0] offset 672876
# Delivered to group3-driver-updates [0] offset 672877
# Delivered to group3-driver-updates [0] offset 672878
# Delivered to group3-driver-updates [0] offset 672879
# Delivered to group3-driver-updates [0] offset 672880
# Delivered to group3-driver-updates [0] offset 672881
# Delivered to group3-driver-updates [0] offset 672882
# Delivered to group3-driver-updates [0] offset 672883
# Delivered to group3-driver-updates [0] offset 672884
# Delivered to group3-driver-updates [0] offset 672885
# Delivered to group3-driver-updates [0] offset 672886
# Delivered to group3-driver-updates [0] offset 672887
# Delivered to group3-driver-updates [0] offset 672888
# Delivered to group3-driver-updates [0] offset 672889
# Delivered to group3-driver-updates [0] offset 672890
# Delivered to group3-driver-updates [0] offset 672891
# Delivered to group3-driver-updates [0] offset 672892
# Delivered to group3-driver-updates [0] offset 672893
# Delivered to group3-driver-updates [0] offset 672894
# Delivered to group3-driver-updates [0] offset 672895
# Delivered to group3-driver-updates [0] offset 672896
# Delivered to group3-driver-updates [0] offset 672897
# Delivered to group3-driver-updates [0] offset 672898
# Delivered to group3-driver-updates [0] offset 672899
# Delivered to group3-driver-updates [0] offset 672900
# Delivered to group3-driver-updates [0] offset 672901
# Delivered to group3-driver-updates [0] offset 672902
# Delivered to group3-driver-updates [0] offset 672903
# Delivered to group3-driver-updates [0] offset 672904
# Delivered to group3-driver-updates [0] offset 672905
# Delivered to group3-driver-updates [0] offset 672906
# Delivered to group3-driver-updates [0] offset 672907
# Delivered to group3-driver-updates [0] offset 672908
# Delivered to group3-driver-updates [0] offset 672909
# Delivered to group3-driver-updates [0] offset 672910
# Delivered to group3-driver-updates [0] offset 672911
# Delivered to group3-driver-updates [0] offset 672912
# Delivered to group3-driver-updates [0] offset 672913
# Delivered to group3-driver-updates [0] offset 672914
# Delivered to group3-driver-updates [0] offset 672915
# Delivered to group3-driver-updates [0] offset 672916
# Delivered to group3-driver-updates [0] offset 672917
# Delivered to group3-driver-updates [0] offset 672918
# Delivered to group3-driver-updates [0] offset 672919
# Delivered to group3-driver-updates [0] offset 672920
# Delivered to group3-driver-updates [0] offset 672921
# Delivered to group3-driver-updates [0] offset 672922
# Delivered to group3-driver-updates [0] offset 672923
# Delivered to group3-driver-updates [0] offset 672924
# Delivered to group3-driver-updates [0] offset 672925
# Delivered to group3-driver-updates [0] offset 672926
# Delivered to group3-driver-updates [0] offset 672927
# Delivered to group3-driver-updates [0] offset 672928
# Delivered to group3-driver-updates [0] offset 672929
# Delivered to group3-driver-updates [0] offset 672930
# Delivered to group3-driver-updates [0] offset 672931
# Delivered to group3-driver-updates [0] offset 672932
# Delivered to group3-driver-updates [0] offset 672933
# Delivered to group3-driver-updates [0] offset 672934
# Delivered to group3-driver-updates [0] offset 672935
# Delivered to group3-driver-updates [0] offset 672936
# Delivered to group3-driver-updates [0] offset 672937
# Delivered to group3-driver-updates [0] offset 672938
# Delivered to group3-driver-updates [0] offset 672939
# Delivered to group3-driver-updates [0] offset 672940
# Delivered to group3-driver-updates [0] offset 672941
# Delivered to group3-driver-updates [0] offset 672942
# Delivered to group3-driver-updates [0] offset 672943
# Delivered to group3-driver-updates [0] offset 672944
# Delivered to group3-driver-updates [0] offset 672945
# Delivered to group3-driver-updates [0] offset 672946
# Delivered to group3-driver-updates [0] offset 672947
# Delivered to group3-driver-updates [0] offset 672948
# Delivered to group3-driver-updates [0] offset 672949
# Delivered to group3-driver-updates [0] offset 672950
# Delivered to group3-driver-updates [0] offset 672951
# Delivered to group3-driver-updates [0] offset 672952
# Delivered to group3-driver-updates [0] offset 672953
# Delivered to group3-driver-updates [0] offset 672954
# Delivered to group3-driver-updates [0] offset 672955
# Delivered to group3-driver-updates [0] offset 672956
# Delivered to group3-driver-updates [0] offset 672957
# Delivered to group3-driver-updates [0] offset 672958
# Delivered to group3-driver-updates [0] offset 672959
# Delivered to group3-driver-updates [0] offset 672960
# Delivered to group3-driver-updates [0] offset 672961
# Delivered to group3-driver-updates [0] offset 672962
# Delivered to group3-driver-updates [0] offset 672963
# Delivered to group3-driver-updates [0] offset 672964
# Delivered to group3-driver-updates [0] offset 672965
# Delivered to group3-driver-updates [0] offset 672966
# Delivered to group3-driver-updates [0] offset 672967
# Delivered to group3-driver-updates [0] offset 672968
# Delivered to group3-driver-updates [0] offset 672969
# Delivered to group3-driver-updates [0] offset 672970
# Delivered to group3-driver-updates [0] offset 672971
# Delivered to group3-driver-updates [0] offset 672972
# Delivered to group3-driver-updates [0] offset 672973
# Delivered to group3-driver-updates [0] offset 672974
# Delivered to group3-driver-updates [0] offset 672975
# Delivered to group3-driver-updates [0] offset 672976
# Delivered to group3-driver-updates [0] offset 672977
# Delivered to group3-driver-updates [0] offset 672978
# Delivered to group3-driver-updates [0] offset 672979
# Delivered to group3-driver-updates [0] offset 672980
# Delivered to group3-driver-updates [0] offset 672981
# Delivered to group3-driver-updates [0] offset 672982
# Delivered to group3-driver-updates [0] offset 672983
# Delivered to group3-driver-updates [0] offset 672984
# Delivered to group3-driver-updates [0] offset 672985
# Delivered to group3-driver-updates [0] offset 672986
# Delivered to group3-driver-updates [0] offset 672987
# Delivered to group3-driver-updates [0] offset 672988
# Delivered to group3-driver-updates [0] offset 672989
# Delivered to group3-driver-updates [0] offset 672990
# Delivered to group3-driver-updates [0] offset 672991
# Delivered to group3-driver-updates [0] offset 672992
# Delivered to group3-driver-updates [0] offset 672993
# Delivered to group3-driver-updates [0] offset 672994
# Delivered to group3-driver-updates [0] offset 672995
# Delivered to group3-driver-updates [0] offset 672996
# Delivered to group3-driver-updates [0] offset 672997
# Delivered to group3-driver-updates [0] offset 672998
# Delivered to group3-driver-updates [0] offset 672999
# Delivered to group3-driver-updates [0] offset 673000
# Delivered to group3-driver-updates [0] offset 673001
# Delivered to group3-driver-updates [0] offset 673002
# Delivered to group3-driver-updates [0] offset 673003
# Delivered to group3-driver-updates [0] offset 673004
# Delivered to group3-driver-updates [0] offset 673005
# Delivered to group3-driver-updates [0] offset 673006
# Delivered to group3-driver-updates [0] offset 673007
# Delivered to group3-driver-updates [0] offset 673008
# Delivered to group3-driver-updates [0] offset 673009
# Delivered to group3-driver-updates [0] offset 673010
# Delivered to group3-driver-updates [0] offset 673011
# Delivered to group3-driver-updates [0] offset 673012
# Delivered to group3-driver-updates [0] offset 673013
# Delivered to group3-driver-updates [0] offset 673014
# Delivered to group3-driver-updates [0] offset 673015
# Delivered to group3-driver-updates [0] offset 673016
# Delivered to group3-driver-updates [0] offset 673017
# Delivered to group3-driver-updates [0] offset 673018
# Delivered to group3-driver-updates [0] offset 673019
# Delivered to group3-driver-updates [0] offset 673020
# Delivered to group3-driver-updates [0] offset 673021
# Delivered to group3-driver-updates [0] offset 673022
# Delivered to group3-driver-updates [0] offset 673023
# Delivered to group3-driver-updates [0] offset 673024
# Delivered to group3-driver-updates [0] offset 673025
# Delivered to group3-driver-updates [0] offset 673026
# Delivered to group3-driver-updates [0] offset 673027
# Delivered to group3-driver-updates [0] offset 673028
# Delivered to group3-driver-updates [0] offset 673029
# Delivered to group3-driver-updates [0] offset 673030
# Delivered to group3-driver-updates [0] offset 673031
# Delivered to group3-driver-updates [0] offset 673032
# Delivered to group3-driver-updates [0] offset 673033
# Delivered to group3-driver-updates [0] offset 673034
# Delivered to group3-driver-updates [0] offset 673035
# Delivered to group3-driver-updates [0] offset 673036
# Delivered to group3-driver-updates [0] offset 673037
# Delivered to group3-driver-updates [0] offset 673038
# Delivered to group3-driver-updates [0] offset 673039
# Delivered to group3-driver-updates [0] offset 673040
# Delivered to group3-driver-updates [0] offset 673041
# Delivered to group3-driver-updates [0] offset 673042
# Delivered to group3-driver-updates [0] offset 673043
# Delivered to group3-driver-updates [0] offset 673044
# Delivered to group3-driver-updates [0] offset 673045
# Delivered to group3-driver-updates [0] offset 673046
# Delivered to group3-driver-updates [0] offset 673047
# Delivered to group3-driver-updates [0] offset 673048
# Delivered to group3-driver-updates [0] offset 673049
# Delivered to group3-driver-updates [0] offset 673050
# Delivered to group3-driver-updates [0] offset 673051
# Delivered to group3-driver-updates [0] offset 673052
# Delivered to group3-driver-updates [0] offset 673053
# Delivered to group3-driver-updates [0] offset 673054
# Delivered to group3-driver-updates [0] offset 673055
# Delivered to group3-driver-updates [0] offset 673056
# Delivered to group3-driver-updates [0] offset 673057
# Delivered to group3-driver-updates [0] offset 673058
# Delivered to group3-driver-updates [0] offset 673059
# Delivered to group3-driver-updates [0] offset 673060
# Delivered to group3-driver-updates [0] offset 673061
# Delivered to group3-driver-updates [0] offset 673062
# Delivered to group3-driver-updates [0] offset 673063
# Delivered to group3-driver-updates [0] offset 673064
# Delivered to group3-driver-updates [0] offset 673065
# Delivered to group3-driver-updates [0] offset 673066
# Delivered to group3-driver-updates [0] offset 673067
# Delivered to group3-driver-updates [0] offset 673068
# Delivered to group3-driver-updates [0] offset 673069
# Delivered to group3-driver-updates [0] offset 673070
# Delivered to group3-driver-updates [0] offset 673071
# Delivered to group3-driver-updates [0] offset 673072
# Delivered to group3-driver-updates [0] offset 673073
# Delivered to group3-driver-updates [0] offset 673074
# Delivered to group3-driver-updates [0] offset 673075
# Delivered to group3-driver-updates [0] offset 673076
# Delivered to group3-driver-updates [0] offset 673077
# Delivered to group3-driver-updates [0] offset 673078
# Delivered to group3-driver-updates [0] offset 673079
# Delivered to group3-driver-updates [0] offset 673080
# Delivered to group3-driver-updates [0] offset 673081
# Delivered to group3-driver-updates [0] offset 673082
# Delivered to group3-driver-updates [0] offset 673083
# Delivered to group3-driver-updates [0] offset 673084
# Delivered to group3-driver-updates [0] offset 673085
# Delivered to group3-driver-updates [0] offset 673086
# Delivered to group3-driver-updates [0] offset 673087
# Delivered to group3-driver-updates [0] offset 673088
# Delivered to group3-driver-updates [0] offset 673089
# Delivered to group3-driver-updates [0] offset 673090
# Delivered to group3-driver-updates [0] offset 673091
# Delivered to group3-driver-updates [0] offset 673092
# Delivered to group3-driver-updates [0] offset 673093
# Delivered to group3-driver-updates [0] offset 673094
# Delivered to group3-driver-updates [0] offset 673095
# Delivered to group3-driver-updates [0] offset 673096
# Delivered to group3-driver-updates [0] offset 673097
# Delivered to group3-driver-updates [0] offset 673098
# Delivered to group3-driver-updates [0] offset 673099
# Delivered to group3-driver-updates [0] offset 673100
# Delivered to group3-driver-updates [0] offset 673101
# Delivered to group3-driver-updates [0] offset 673102
# Delivered to group3-driver-updates [0] offset 673103
# Delivered to group3-driver-updates [0] offset 673104
# Delivered to group3-driver-updates [0] offset 673105
# Delivered to group3-driver-updates [0] offset 673106
# Delivered to group3-driver-updates [0] offset 673107
# Delivered to group3-driver-updates [0] offset 673108
# Delivered to group3-driver-updates [0] offset 673109
# Delivered to group3-driver-updates [0] offset 673110
# Delivered to group3-driver-updates [0] offset 673111
# Delivered to group3-driver-updates [0] offset 673112
# Delivered to group3-driver-updates [0] offset 673113
# Delivered to group3-driver-updates [0] offset 673114
# Delivered to group3-driver-updates [0] offset 673115
# Delivered to group3-driver-updates [0] offset 673116
# Delivered to group3-driver-updates [0] offset 673117
# Delivered to group3-driver-updates [0] offset 673118
# Delivered to group3-driver-updates [0] offset 673119
# Delivered to group3-driver-updates [0] offset 673120
# Delivered to group3-driver-updates [0] offset 673121
# Delivered to group3-driver-updates [0] offset 673122
# Delivered to group3-driver-updates [0] offset 673123
# Delivered to group3-driver-updates [0] offset 673124
# Delivered to group3-driver-updates [0] offset 673125
# Delivered to group3-driver-updates [0] offset 673126
# Delivered to group3-driver-updates [0] offset 673127
# Delivered to group3-driver-updates [0] offset 673128
# Delivered to group3-driver-updates [0] offset 673129
# Delivered to group3-driver-updates [0] offset 673130
# Delivered to group3-driver-updates [0] offset 673131
# Delivered to group3-driver-updates [0] offset 673132
# Delivered to group3-driver-updates [0] offset 673133
# Delivered to group3-driver-updates [0] offset 673134
# Delivered to group3-driver-updates [0] offset 673135
# Delivered to group3-driver-updates [0] offset 673136
# Delivered to group3-driver-updates [0] offset 673137
# Delivered to group3-driver-updates [0] offset 673138
# Delivered to group3-driver-updates [0] offset 673139
# Delivered to group3-driver-updates [0] offset 673140
# Delivered to group3-driver-updates [0] offset 673141
# Delivered to group3-driver-updates [0] offset 673142
# Delivered to group3-driver-updates [0] offset 673143
# Delivered to group3-driver-updates [0] offset 673144
# Delivered to group3-driver-updates [0] offset 673145
# Delivered to group3-driver-updates [0] offset 673146
# Delivered to group3-driver-updates [0] offset 673147
# Delivered to group3-driver-updates [0] offset 673148
# Delivered to group3-driver-updates [0] offset 673149
# Delivered to group3-driver-updates [0] offset 673150
# Delivered to group3-driver-updates [0] offset 673151
# Delivered to group3-driver-updates [0] offset 673152
# Delivered to group3-driver-updates [0] offset 673153
# Delivered to group3-driver-updates [0] offset 673154
# Delivered to group3-driver-updates [0] offset 673155
# Delivered to group3-driver-updates [0] offset 673156
# Delivered to group3-driver-updates [0] offset 673157
# Delivered to group3-driver-updates [0] offset 673158
# Delivered to group3-driver-updates [0] offset 673159
# Delivered to group3-driver-updates [0] offset 673160
# Delivered to group3-driver-updates [0] offset 673161
# Delivered to group3-driver-updates [0] offset 673162
# Delivered to group3-driver-updates [0] offset 673163
# Delivered to group3-driver-updates [0] offset 673164
# [EventHub] Sent driver update for driver_101
# [Simulation End] Simulation complete.
# Delivered to group3-passenger_requests [1] offset 240954
# Delivered to group3-driver-updates [0] offset 673165
